# %%
# Deep Learning + Medics + Audio Data
# LSTM lifecycle + Cardiac working and heart sounds + Spectrum and MFCC

# %%
import kagglehub
import os # Fetch data
import glob
import pandas as pd # Loading data
import numpy as np # Processing
import librosa # For audio files
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt
import IPython.display as ipd
import math
import tensorflow as tf

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import concatenate

from tensorflow.keras.models import Sequential, Model, Load_model

from tensorflow.keras.layers import Conv1D, Conv2D, SeperableConv1D, MaxPooling1D, MaxPooling2d
from tensorflow.keras.layers import Input, add, Flatten, Dense, BatchNormilization, Dropout, LSTM, GRU
from tensorflow.keras.layers import GlobalMaxPooling1D, GlobalMaxPooling2D, Activation, LeakyReLU, ReLU

from tensorflow.keras import regulaizers
from tensorflow.keras import backend as k
from tensorflow.keras.optimizers import Adamax
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 4
#       1 from tensorflow.keras.utils import to_categorical
#       2 from tensorflow.keras.layers import concatenate
# ----> 4 from tensorflow.keras.models import Sequential, Model, Load_model
#       6 from tensorflow.keras.layers import Conv1D, Conv2D, SeperableConv1D, MaxPooling1D, MaxPooling2d
#       7 from tensorflow.keras.layers import Input, add, Flatten, Dense, BatchNormilization, Dropout, LSTM, GRU
#
# ImportError: cannot import name 'Load_model' from 'tensorflow.keras.models' (C:\Users\Sandeep\anaconda3\Lib\site-packages\keras\_tf_keras\keras\models\__init__.py)

# %%
# Load data from kaggle
path = kagglehub.dataset_download("abdallahaboelkhair/heartbeat-sound")

print("Path to dataset:", path)
# Out:
# Downloading to C:\Users\Sandeep\.cache\kagglehub\datasets\abdallahaboelkhair\heartbeat-sound\1.archive...
# 100%|███████████████████████████████████████████████████████████████████████████████| 110M/110M [00:03<00:00, 30.2MB/s]
# Extracting files...
# Path to dataset: C:\Users\Sandeep\.cache\kagglehub\datasets\abdallahaboelkhair\heartbeat-sound\versions\1

# %%
# Cleaning EDA
